# %%
import pymoo


import torch
import numpy as np

import matplotlib.pyplot as plt

# %%
from pymoo.factory import get_problem, get_reference_directions, get_visualization
from pymoo.util.plotting import plot

ref_dirs = get_reference_directions("das-dennis", 3, n_partitions=12)

pf = get_problem("dtlz1").pareto_front(ref_dirs)
get_visualization("scatter", angle=(45,45)).add(pf).show()

# %%
get_problem("dtlz1")

# %%
a = get_problem("ackley", n_var=2, a=20, b=1/5, c=2 * np.pi)

# %%
dir(a)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_calc_pareto_front',
#  '_calc_pareto_set',
#  '_evaluate',
#  '_ideal_point',
#  '_nadir_point',
#  '_pareto_front',
#  '_pareto_set',
#  'a',
#  'b',
#  'bounds',
#  'c',
#  'calc_constraint_violation',
#  'callback',
#  'check_inconsistencies',
#  'data',
#  'do',
#  'evaluate',
#  'exclude_from_serialization',
#  'has_bounds',
#  'has_constraints',
#  'ideal_point',
#  'n_constr',
#  'n_obj',
#  'n_var',
#  'nadir_point',
#  'name',
#  'pareto_front',
#  'pareto_set',
#  'replace_nan_values_by',
#  'xl',
#  'xu']

# %%
x = [1,2]

# x = np.array(x)
x = torch.tensor(x)
a.evaluate(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/fk/0sthbc6s2zbd1kyry1yjdxzw0000gn/T/ipykernel_17474/1583723301.py in <module>
#       3 # x = np.array(x)
#       4 x = torch.tensor(x)
# ----> 5 a.evaluate(x)
#
# ~/miniconda3/lib/python3.9/site-packages/pymoo/core/problem.py in evaluate(self, X, return_values_of, return_as_dictionary, *args, **kwargs)
#     109
#     110         # make sure the array is at least 2d. store if reshaping was necessary
# --> 111         X, only_single_value = at_least_2d_array(X, extend_as="row", return_if_reshaped=True)
#     112         assert X.shape[1] == self.n_var, f'Input dimension {X.shape[1]} are not equal to n_var {self.n_var}!'
#     113
#
# ~/miniconda3/lib/python3.9/site-packages/pymoo/util/misc.py in at_least_2d_array(x, extend_as, return_if_reshaped)
#     208         return x
#     209     elif not isinstance(x, np.ndarray):
# --> 210         x = np.array([x])
#     211
#     212     has_been_reshaped = False
#
# ValueError: only one element tensors can be converted to Python scalars
